# %%
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector
from sqlalchemy.exc import ResourceClosedError,IntegrityError

# %%
host="localhost",
user="root",
password="root",
database="airline"
port=3306

# %%
engine = create_engine('mysql+pymysql://root:root@localhost:3306/airline')
conn = engine.connect()

# %%
mydb = mysql.connector.connect(host="localhost",user="root",password="root",database="airline")
mycursor = mydb.cursor()

# %%
def search_flights():
    from_ = input('From :')
    to_ = input('To : ')
    date_ = input('Date : ')
    exists = False
    df = pd.read_sql_query(f'call FlightSearch("{from_}","{to_}","{date_}")',engine)
    if df.empty:
        print('There is no Fights ')
    else:
        display(df)
        exists = True
        return {'df':df,'exists':exists}

def book_flights():
    print('Login Required. Press 3')

def flight_booking(flight_name,flight_code):
    fname = input('Enter First Name: ')
    mname = input('Enter middle Name: ')
    lname = input('Enter last Name: ')
    mob = input('Enter phone number: ')
    mail = input('Enter email number: ')
    passport = input('Enter passport:')
    country = input('Enter country code: ')
#     flight_name = input('Enter flight name: ')
#     flight_code = int(input('Enter flight code: '))
    try:
        mycursor.callproc("flightbooking", [fname,mname,lname,mob,mail,passport,country,flight_name,flight_code])
        mydb.commit()
        value = pd.read_sql_query(f'call FlightBooking1({flight_code})',engine)
        display(value)
    except mysql.connector.IntegrityError:
        print("Don't Insert Duplicate Value.")

    
    
    
def login():
    flag = True
    print('Login')
    username = input('Enter email : ')
    password = input('Enter Password :')
    print('\n')
    df = pd.read_sql_query(f'select * from register where email="{username}" and password="{password}"',engine)
    if df.empty:
        print("There is no username exists. Please Enter Valid Username and Password.")
    else:
        while flag:
            print('\n')
            print('Press 1: Book Flight')
            print('Press 2: View Bookings')
            print('Press 3: Check Flight Status')
            print('Press 4: Cancel Booking')
            print('Press 5: LOGOUT')
            choose = int(input('Please Enter Number.... : '))

            if choose == 1:
                value = search_flights()
                if value['exists']:
                    row = int(input('Please Enter the Row Number : '))
                    flight_name = str(value['df'].iloc[row][1])
                    flight_code = int(value['df'].iloc[row][0])
                    flight_booking(flight_name,flight_code)
            elif choose == 2:
                check_booking()
            elif choose == 3:
                CheckFlightStatus()
            elif choose == 4:
                pass
            elif choose == 5:
                flag = False
            else:
                print('Please Enter valid number which are mentioned as options.')
            

def register():
    print('\n')
    print('Register')
    flag = True
    while flag:
        name = input('Enter Your Name :')
        email = input('Enter Your Email : ')
        password = input('Enter Password :')
        confirm = input('Enter Password Again :')
        if password == confirm:
            try:
                pd.read_sql_query(f'insert into register values("{name}","{email}","{password}")',engine)
                flag = False
            except ResourceClosedError:
                login()
                flag = False
            except IntegrityError:
                print('Username already Exits. Try with another username and email.')
                continue
        else:
            print("Please enter Password Correctly")

def CheckFlightStatus():
    number = int(input('Enter Flight No. : '))
    df = pd.read_sql_query(f'call CheckFlightStatus("{number}")',engine)
    if df.empty:
        print("There is no flight on this number.")
    else:
        display(df)

def check_booking():
    pid = int(input("Enter your ID : "))
    df = pd.read_sql_query(f'call checkbooking({pid});',engine)
    if df.empty:
        print('There is no result found.')
    else:
        display(df)

# %%
def main():
    flag = True
    while flag:
        print('Flight Booking systems')
        print('\n')
        print('Press 1 : Search Flights')
        print('Press 2 : Book Flights')
        print('Press 3 : Login')
        print('Press 4 : Register')
        print('Press 0 : Exit')
        
        choose = int(input('Press Key'))
        
        if choose == 1:
            search_flights()
            print('\n')
        elif choose == 2:
            book_flights()
            print('\n')
        elif choose == 3:
            login()
            print('\n')
        elif choose == 4:
            register()
            print('\n')
        elif choose == 0:
            print('Thank You')
            flag = False
            break

main()
# Out:
# Flight Booking systems
#
#
# Press 1 : Search Flights
# Press 2 : Book Flights
# Press 3 : Login
# Press 4 : Register
# Press 0 : Exit
# Press Key3
# Login
# Enter email : pankaj
# Enter Password :123
#
#
#
#
# Press 1: Book Flight
# Press 2: View Bookings
# Press 3: Check Flight Status
# Press 4: Cancel Booking
# Press 5: LOGOUT
# Please Enter Number.... : 1
# From :CCU
# To : BHM
# Date : 2022-09-10
#    flight_call Flight_Name From_  To_            Dep_Time            Arr_Time  \
# 0         3762   Air India   CCU  BHM 2022-09-10 01:56:47 2022-09-11 15:34:38
# 1         3763    Air Asia   CCU  BHM 2022-09-10 01:56:47 2022-09-11 15:34:38
#
#       Price    Class
# 0   6788.54  Economy
# 1  45758.51  Economy
# Please Enter the Row Number : 0
# Enter First Name: Pankaj
# Enter middle Name: Kumar
# Enter last Name: Bhoi
# Enter phone number: 741852963
# Enter email number: pankaj
# Enter passport:741852963
# Enter country code: IN
#           Name From_  To_          Dept_Time_            Arr_Time Flight_name  \
# 0  Pankaj Bhoi   CCU  BHM 2022-09-10 01:56:47 2022-09-11 15:34:38   Air India
#
#      class    Bstatus
# 0  Economy  Confirmed
# Press 1: Book Flight
# Press 2: View Bookings
# Press 3: Check Flight Status
# Press 4: Cancel Booking
# Press 5: LOGOUT

# %%
def 
print('Please enter following details: ')

fname = input('Enter First Name: ')
mname = input('Enter middle Name: ')
lname = input('Enter last Name: ')
mob = input('Enter phone number: ')
mail = input('Enter email number: ')
passport = input('Enter passport:')
country = input('Enter country code: ')

try:
    mycursor.callproc("flightbooking", [fname,mname,lname,mob,mail,passport,country,flight_name,flight_code])
    mydb.commit()
    value = pd.read_sql_query(f'call FlightBooking1({flight_id})',engine)
    display(value)
except mysql.connector.IntegrityError:
    print("Don't Insert Duplicate Value.")

# %%
def flight_booking():
    
    print('Please enter following details: ')

    fname = 'Pankaj'
    mname = 'Ku'
    lname = 'Bhoi'
    mob = '45896321'
    mail = 'pk@gmail.com'
    passport = '58963254'
    country = 'IN'
    flight_name = 'Air India'
    flight_code = 3763
    pd.read_sql_query(f"call flightbooking ('{fname}','{mname}','{lname}','{mob}','{mail}','{passport}','{country}','{flight_name}',{flight_code});",engine)
    
    print('Booking Confirmed!')
#     try:
#         value = pd.read_sql_query(f'call flightbooking("{fname}","{mname}","{lname}","{mob}","{mail}","{passport}","{country}","{flight_name}",{int(flight_code)});')
#         print(value)
#         print('Booking Confirmed!')
#     except Error:
#         print('****** Booking Failed ******')

flight_booking()
# Out:
# Please enter following details:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Input In [19], in <cell line: 24>()
#      16     print('Booking Confirmed!')
#      17 #     try:
#      18 #         value = pd.read_sql_query(f'call flightbooking("{fname}","{mname}","{lname}","{mob}","{mail}","{passport}","{country}","{flight_name}",{int(flight_code)});')
#      19 #         print(value)
#      20 #         print('Booking Confirmed!')
#      21 #     except Error:
#      22 #         print('****** Booking Failed ******')
# ---> 24 flight_booking()
#
# Input In [19], in flight_booking()
#      12 flight_name = 'Air India'
#      13 flight_code = 3763
# ---> 14 pd.read_sql_query(f"call flightbooking ('{fname}','{mname}','{lname}','{mob}','{mail}','{passport}','{country}','{flight_name}',{flight_code});",engine)
#      16 print('Booking Confirmed!')
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:399, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     341 """
#     342 Read SQL query into a DataFrame.
#     343
#    (...)
#     396 parameter will be converted to UTC.
#     397 """
#     398 pandas_sql = pandasSQL_builder(con)
# --> 399 return pandas_sql.read_query(
#     400     sql,
#     401     index_col=index_col,
#     402     params=params,
#     403     coerce_float=coerce_float,
#     404     parse_dates=parse_dates,
#     405     chunksize=chunksize,
#     406     dtype=dtype,
#     407 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:1571, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1561     return self._query_iterator(
#    1562         result,
#    1563         chunksize,
#    (...)
#    1568         dtype=dtype,
#    1569     )
#    1570 else:
# -> 1571     data = result.fetchall()
#    1572     frame = _wrap_result(
#    1573         data,
#    1574         columns,
#    (...)
#    1578         dtype=dtype,
#    1579     )
#    1580     return frame
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:1015, in Result.fetchall(self)
#    1012 def fetchall(self):
#    1013     """A synonym for the :meth:`_engine.Result.all` method."""
# -> 1015     return self._allrows()
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:399, in ResultInternal._allrows(self)
#     395 def _allrows(self):
#     397     post_creational_filter = self._post_creational_filter
# --> 399     make_row = self._row_getter
#     401     rows = self._fetchall_impl()
#     402     if make_row:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1180, in HasMemoized.memoized_attribute.__get__(self, obj, cls)
#    1178 if obj is None:
#    1179     return self
# -> 1180 obj.__dict__[self.__name__] = result = self.fget(obj)
#    1181 obj._memoized_keys |= {self.__name__}
#    1182 return result
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:320, in ResultInternal._row_getter(self)
#     317 key_style = real_result._process_row._default_key_style
#     318 metadata = self._metadata
# --> 320 keymap = metadata._keymap
#     321 processors = metadata._processors
#     322 tf = metadata._tuplefilter
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1208, in _NoResultMetaData._keymap(self)
#    1206 @property
#    1207 def _keymap(self):
# -> 1208     self._we_dont_return_rows()
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1189, in _NoResultMetaData._we_dont_return_rows(self, err)
#    1188 def _we_dont_return_rows(self, err=None):
# -> 1189     util.raise_(
#    1190         exc.ResourceClosedError(
#    1191             "This result object does not return rows. "
#    1192             "It has been closed automatically."
#    1193         ),
#    1194         replace_context=err,
#    1195     )
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
def flight_booking():
        print('Please enter following details: ')

        fname = input('Enter First Name: ')
        mname = input('Enter middle Name: ')
        lname = input('Enter last Name: ')
        mob = input('Enter phone number: ')
        mail = input('Enter email number: ')
        passport = input('Enter passport:')
        country = input('Enter country code: ')
        flight_name = input('Enter flight name: ')
        flight_code = int(input('Enter flight code: '))

        try:
            engine.execute(f"call flightbooking ('{fname}','{mname}','{lname}','{mob}','{mail}','{passport}','{country}','{flight_name}',{flight_code});")
            print('Booking Confirmed!')
        except:
            print('****** Booking Failed ******')

# %%
df = pd.read_sql_query(f'call FlightSearch("CCU","BHM","2022-09-10")',engine)
df
# Out:
#    flight_call Flight_Name From_  To_            Dep_Time            Arr_Time  \
# 0         3762   Air India   CCU  BHM 2022-09-10 01:56:47 2022-09-11 15:34:38
# 1         3763    Air Asia   CCU  BHM 2022-09-10 01:56:47 2022-09-11 15:34:38
#
#       Price    Class
# 0   6788.54  Economy
# 1  45758.51  Economy
